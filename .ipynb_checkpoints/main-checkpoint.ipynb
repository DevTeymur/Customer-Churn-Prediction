# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm, skew

from collections import Counter

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, roc_curve, precision_score, recall_score, precision_recall_curve
from sklearn.feature_selection import RFE

from warnings import filterwarnings
filterwarnings('ignore')
print("All done")
# Out:
# All done

# %% [markdown]
# ## Reading the data

# %%
data = pd.read_csv('churn_prediction.csv')

# %%
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28382 entries, 0 to 28381
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     28382 non-null  int64
#  1   vintage                         28382 non-null  int64
#  2   age                             28382 non-null  int64
#  3   gender                          27857 non-null  object
#  4   dependents                      25919 non-null  float64
#  5   occupation                      28302 non-null  object
#  6   city                            27579 non-null  float64
#  7   customer_nw_category            28382 non-null  int64
#  8   branch_code                     28382 non-null  int64
#  9   days_since_last_transaction     25159 non-null  float64
#  10  current_balance                 28382 non-null  float64
#  11  previous_month_end_balance      28382 non-null  float64
#  12  average_monthly_balance_prevQ   28382 non-null  float64
#  13  average_monthly_balance_prevQ2  28382 non-null  float64
#  14  current_month_credit            28382 non-null  float64
#  15  previous_month_credit           28382 non-null  float64
#  16  current_month_debit             28382 non-null  float64
#  17  previous_month_debit            28382 non-null  float64
#  18  current_month_balance           28382 non-null  float64
#  19  previous_month_balance          28382 non-null  float64
#  20  churn                           28382 non-null  int64
# dtypes: float64(13), int64(6), object(2)
# memory usage: 4.5+ MB

# %% [markdown]
# ### Meaning of some categiories
#
# <b>vintage</b> - Vintage of the customer with the bank in number of days
#
# <b>dependents</b> - Number of dependents
#
# <b>customer_nw_category</b> - Net worth of customer (3:Low 2:Medium 1:High)
#
# <b>branch_code</b> - Branch Code for customer account
#
# <b>days_since_last_transaction</b> - No of Days Since Last Credit in Last 1 year
#
# <b>average_monthly_balance_prevQ</b> - Average monthly balances (AMB) in Previous Quarter
#
# <b>average_monthly_balance_prevQ2</b> - Average monthly balances (AMB) in previous to previous quarter
#
# <b>churn</b> - Average balance of customer falls below minimum balance in the next quarter (1/0)

# %%
df.shape
# Out:
# (28382, 21)

# %%
df.head(7)
# Out:
#    customer_id  vintage  age  gender  dependents     occupation    city  \
# 0            1     3135   66    Male         0.0  self_employed   187.0
# 1            2      310   35    Male         0.0  self_employed     NaN
# 2            4     2356   31    Male         0.0       salaried   146.0
# 3            5      478   90     NaN         NaN  self_employed  1020.0
# 4            6     2531   42    Male         2.0  self_employed  1494.0
# 5            7      263   42  Female         0.0  self_employed  1096.0
# 6            8     5922   72    Male         0.0        retired  1020.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
# 5                     2         1666                         60.0  ...
# 6                     1            1                         98.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
# 2                     5815.29                        4910.17
# 3                     2291.91                        2084.54
# 4                     1401.72                        1643.31
# 5                    16059.34                       15211.29
# 6                     7714.19                        7859.74
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
# 2                         2815.94                  0.61
# 3                         1006.54                  0.47
# 4                         1871.12                  0.33
# 5                        13798.82                  0.36
# 6                        11232.37                  0.64
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
# 5                   0.36               857.50                286.07
# 6                   0.64              1299.64                439.26
#
#    current_month_balance  previous_month_balance  churn
# 0                1458.71                 1458.71      0
# 1                6496.78                 8787.61      0
# 2                5006.28                 5070.14      0
# 3                2291.91                 1669.79      1
# 4                1157.15                 1677.16      1
# 5               15719.44                15349.75      0
# 6                7076.06                 7755.98      0
#
# [7 rows x 21 columns]

# %% [markdown]
# ## Missing values

# %%
df.isnull().sum()
# Out:
# customer_id                          0
# vintage                              0
# age                                  0
# gender                             525
# dependents                        2463
# occupation                          80
# city                               803
# customer_nw_category                 0
# branch_code                          0
# days_since_last_transaction       3223
# current_balance                      0
# previous_month_end_balance           0
# average_monthly_balance_prevQ        0
# average_monthly_balance_prevQ2       0
# current_month_credit                 0
# previous_month_credit                0
# current_month_debit                  0
# previous_month_debit                 0
# current_month_balance                0
# previous_month_balance               0
# churn                                0
# dtype: int64

# %% [markdown]
# Let's analyze every column that contains Null values

# %% [markdown]
# ### Gender

# %%
df.gender.value_counts()
# Out:
# Male      16548
# Female    11309
# Name: gender, dtype: int64

# %% [markdown]
# We cannot say whether missing customer is male or fmale with the information that we have. Let's encode gender column and assign -1 to the missing rows

# %%
df = df.replace({'gender': {'Male': 1, 'Female': 0}})
df.gender = df.gender.fillna(-1)

# %% [markdown]
# ### Dependents

# %%
df.dependents.value_counts()
# Out:
# 0.0     21435
# 2.0      2150
# 1.0      1395
# 3.0       701
# 4.0       179
# 5.0        41
# 6.0         8
# 7.0         3
# 36.0        1
# 52.0        1
# 25.0        1
# 9.0         1
# 50.0        1
# 32.0        1
# 8.0         1
# Name: dependents, dtype: int64

# %% [markdown]
# Filling missing values with 0 as most of the customers have 0 dependents

# %%
df.dependents = df.dependents.fillna(0)

# %% [markdown]
# ### Occupation

# %%
df.occupation.value_counts()
# Out:
# self_employed    17476
# salaried          6704
# student           2058
# retired           2024
# company             40
# Name: occupation, dtype: int64

# %% [markdown]
# Again we can fill nissing values with the most common category

# %%
df.occupation = df.occupation.fillna('self_employed')

# %% [markdown]
# ### City

# %%
df.city.value_counts()
# Out:
# 1020.0    3479
# 1096.0    2016
# 409.0     1334
# 146.0     1291
# 834.0     1138
#           ...
# 629.0        1
# 527.0        1
# 1212.0       1
# 530.0        1
# 70.0         1
# Name: city, Length: 1604, dtype: int64

# %% [markdown]
# Same stategy can be done for the city column

# %%
df.city = df.city.fillna(1020)

# %% [markdown]
# ### Days since last transaction

# %%
df.days_since_last_transaction.value_counts()
# Out:
# 0.0      1672
# 3.0       831
# 14.0      654
# 4.0       632
# 6.0       596
#          ...
# 170.0       1
# 218.0       1
# 334.0       1
# 288.0       1
# 321.0       1
# Name: days_since_last_transaction, Length: 360, dtype: int64

# %%
# df = df[df.days_since_last_transaction.notna()]
df['days_since_last_transaction'] = df['days_since_last_transaction'].fillna(999)

# %%
print('Total null values: %d' % df.isnull().sum().sum())
# Out:
# Total null values: 0

# %% [markdown]
# ## EDA

# %%
plt.style.use('seaborn')

# %%
plt.figure(figsize=(8,5))
plt.bar(data.gender.value_counts().index, data.gender.value_counts().values)
plt.title('Male/Female distribution')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df.age, bins=8, kde=True)
plt.title('Count by age interval')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(df.churn.value_counts().index, df.churn.value_counts().values)
plt.title('Churn distribution')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(df.occupation.value_counts().index, df.occupation.value_counts().values)
plt.title('Occupation')
plt.show()

# %% [markdown]
# We can see significan difference for different occupations

# %%
most_frequent = df.vintage.value_counts()[:20].index
for i in most_frequent:
    print(f'Vintage {i} - {Counter(df[df.vintage==i].churn.values)}')
# Out:
# Vintage 1432 - Counter({0: 21, 1: 4})
# Vintage 1997 - Counter({0: 20, 1: 3})
# Vintage 403 - Counter({0: 17, 1: 4})
# Vintage 1718 - Counter({0: 17, 1: 3})
# Vintage 1400 - Counter({0: 16, 1: 4})
# Vintage 439 - Counter({0: 18, 1: 1})
# Vintage 984 - Counter({0: 15, 1: 4})
# Vintage 626 - Counter({0: 13, 1: 6})
# Vintage 287 - Counter({0: 13, 1: 6})
# Vintage 1169 - Counter({0: 14, 1: 5})
# Vintage 1394 - Counter({0: 16, 1: 3})
# Vintage 1460 - Counter({0: 14, 1: 4})
# Vintage 2665 - Counter({0: 14, 1: 4})
# Vintage 1342 - Counter({0: 13, 1: 5})
# Vintage 2412 - Counter({0: 15, 1: 3})
# Vintage 625 - Counter({0: 16, 1: 2})
# Vintage 1984 - Counter({0: 15, 1: 3})
# Vintage 1036 - Counter({0: 15, 1: 3})
# Vintage 1395 - Counter({0: 16, 1: 2})
# Vintage 2258 - Counter({0: 15, 1: 3})

# %% [markdown]
# For the most frequent vintage values we can mostly see non-churning customers

# %%
df.columns
# Out:
# Index(['customer_id', 'vintage', 'age', 'gender', 'dependents', 'occupation',
#        'city', 'customer_nw_category', 'branch_code',
#        'days_since_last_transaction', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit', 'previous_month_debit',
#        'current_month_balance', 'previous_month_balance', 'churn'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    customer_id  vintage  age  gender  dependents     occupation    city  \
# 0            1     3135   66     1.0         0.0  self_employed   187.0
# 1            2      310   35     1.0         0.0  self_employed  1020.0
# 2            4     2356   31     1.0         0.0       salaried   146.0
# 3            5      478   90    -1.0         0.0  self_employed  1020.0
# 4            6     2531   42     1.0         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                        999.0  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
# 2                     5815.29                        4910.17
# 3                     2291.91                        2084.54
# 4                     1401.72                        1643.31
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
# 2                         2815.94                  0.61
# 3                         1006.54                  0.47
# 4                         1871.12                  0.33
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
#
#    current_month_balance  previous_month_balance  churn
# 0                1458.71                 1458.71      0
# 1                6496.78                 8787.61      0
# 2                5006.28                 5070.14      0
# 3                2291.91                 1669.79      1
# 4                1157.15                 1677.16      1
#
# [5 rows x 21 columns]

# %%
cols = ['vintage', 'age', 'days_since_last_transaction', 'current_balance',
       'previous_month_end_balance', 'average_monthly_balance_prevQ', 'average_monthly_balance_prevQ2',
       'current_month_credit', 'previous_month_credit', 'current_month_debit', 'previous_month_debit', 
       'current_month_balance', 'previous_month_balance']

# %%
len(cols)
# Out:
# 13

# %%
fig, ax = plt.subplots(5, 3, figsize=(25, 35))
row, col = 0, 0

for i in range(len(cols)):
    sns.boxplot(df[cols[i]], ax=ax[row][col])
    col+=1
    if col==3:
        row+=1
        col=0

# %% [markdown]
# We can see a lot of outliers in different columns.

# %%
fig, ax = plt.subplots(5, 3, figsize=(25, 35))
row, col = 0, 0

for i in range(len(cols)):
    sns.distplot(df[cols[i]], fit=norm, ax=ax[row][col])
    col+=1
    if col==3:
        row+=1
        col=0

# %% [markdown]
# Also, most columns contain skewed distributions.

# %% [markdown]
# ## Encoding

# %% [markdown]
# Before building model we encode categorical columns to numerical

# %%
# encoded = pd.get_dummies(df)
df = pd.concat([df,pd.get_dummies(df['occupation'],prefix = str('occupation'),prefix_sep='_')],axis = 1)

# %% [markdown]
# ## Scailing

# %%
num_cols = ['customer_nw_category', 'current_balance',
            'previous_month_end_balance', 'average_monthly_balance_prevQ2', 'average_monthly_balance_prevQ',
            'current_month_credit','previous_month_credit', 'current_month_debit', 
            'previous_month_debit','current_month_balance', 'previous_month_balance']

# %% [markdown]
# Log Transformation

# %%
for i in num_cols:
    df[i] = np.log(df[i] + 17000)

# %% [markdown]
# Standard Scailer

# %%
std = StandardScaler()
scaled = std.fit_transform(df[num_cols])
scaled = pd.DataFrame(scaled,columns=num_cols).dropna()

# %%
df_df_og = df.copy()
df = df.drop(columns = num_cols, axis = 1)
df = df.merge(scaled, left_index=True, right_index=True, how = "left")

# %%
y = df.churn

# %%
df = df.drop(['churn','customer_id', 'occupation'], axis = 1)

# %%
df.head()
# Out:
#    vintage  age  gender  dependents    city  branch_code  \
# 0     3135   66     1.0         0.0   187.0          755
# 1      310   35     1.0         0.0  1020.0         3214
# 2     2356   31     1.0         0.0   146.0           41
# 3      478   90    -1.0         0.0  1020.0          582
# 4     2531   42     1.0         2.0  1494.0          388
#
#    days_since_last_transaction  occupation_company  occupation_retired  \
# 0                        224.0                   0                   0
# 1                         60.0                   0                   0
# 2                        999.0                   0                   0
# 3                        147.0                   0                   0
# 4                         58.0                   0                   0
#
#    occupation_salaried  ...  current_balance  previous_month_end_balance  \
# 0                    0  ...        -0.613738                   -0.632367
# 1                    0  ...         0.011267                    0.446458
# 2                    1  ...        -0.209651                    0.057975
# 3                    0  ...        -0.470836                   -0.488530
# 4                    0  ...        -0.708214                   -0.642441
#
#    average_monthly_balance_prevQ2  average_monthly_balance_prevQ  \
# 0                       -0.630646                      -0.697612
# 1                        0.949414                       0.317595
# 2                       -0.388637                      -0.108263
# 3                       -0.712855                      -0.582976
# 4                       -0.554058                      -0.663399
#
#    current_month_credit  previous_month_credit  current_month_debit  \
# 0             -0.313931              -0.324487            -0.368251
# 1             -0.313852              -0.324410             0.640986
# 2             -0.313841              -0.324400             0.729825
# 3             -0.313872              -0.324429            -0.368193
# 4             -0.313902              -0.175104            -0.245463
#
#    previous_month_debit  current_month_balance  previous_month_balance
# 0             -0.377390              -0.653455               -0.666207
# 1             -0.355677               0.149440                0.455680
# 2             -0.321607              -0.068597               -0.066642
# 3              0.060593              -0.506570               -0.628056
# 4             -0.057927              -0.708257               -0.626732
#
# [5 rows x 23 columns]

# %%
X = df[['current_month_debit', 'previous_month_debit','current_balance','previous_month_end_balance','vintage'
                 ,'occupation_retired', 'occupation_salaried','occupation_self_employed', 'occupation_student']]

# %% [markdown]
# ## Train Test Split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X ,y, test_size=0.2, random_state=11, stratify = y)

# %%
model = LogisticRegression()
model.fit(Xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
pred = model.predict_proba(Xtest)[:,1]
pred
# Out:
# array([0.1160447 , 0.08922066, 0.25158717, ..., 0.23807007, 0.31216237,
#        0.06753078])

# %%
fpr, tpr, _ = roc_curve(ytest, pred) 
auc = roc_auc_score(ytest, pred) 
plt.figure(figsize=(8,5)) 
plt.plot(fpr,tpr,label="Validation AUC-ROC="+str(auc)) 
x = np.linspace(0, 1, 1000)
plt.plot(x, x, linestyle='-')
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.legend(loc='best') 
plt.show()

# %%
pred_val = model.predict(Xtest)

# %%
label_preds = pred_val

cm = confusion_matrix(ytest, label_preds)


def plot_confusion_matrix(cm, normalized=True, cmap='bone'):
    plt.figure(figsize=[7, 6])
    norm_cm = cm
    if normalized:
        norm_cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        sns.heatmap(norm_cm, annot=cm, fmt='g', xticklabels=['False','True'], yticklabels=['Negative','Positive'], cmap=cmap)

plot_confusion_matrix(cm, ['No', 'Yes'])

# %%
recall_score(ytest, pred_val)
# Out:
# 0.11692015209125475

# %% [markdown]
# ## Cross validation

# %%
def cv_score(algo, rstate = 12, threshold = 0.5, cols = df.columns):
    i = 1
    scores = []
    df1 = df.copy()
    df1 = df[cols]
    
    kf = StratifiedKFold(n_splits=5, random_state=rstate, shuffle=True)
    
    for df_index, test_index in kf.split(df1, y):
        print(f'{i} of {kf.n_splits}')
        xtr,xvl = df1.loc[df_index],df1.loc[test_index]
        ytr,yvl = y.loc[df_index],y.loc[test_index]
        
        model = algo
        model.fit(xtr, ytr)
        pred_probs = model.predict_proba(xvl)
        pp = []
        
        for j in pred_probs[:, 1]:
            if j>threshold:
                pp.append(1)
            else:
                pp.append(0)
                
        pred_val = pp
        roc_score = roc_auc_score(yvl,pred_probs[:,1])
        recall = recall_score(yvl,pred_val)
        precision = precision_score(yvl,pred_val)
        
        print(f'ROC AUC: {roc_score} \nRecall: {recall} \nPrecision: {precision}')
        print('_'*30)
        
        scores.append(roc_score)
        i+=1
    return scores

# %%
baseline_scores = cv_score(LogisticRegression(), cols = X.columns)
# Out:
# 1 of 5
# ROC AUC: 0.7644836090843695
# Recall: 0.07509505703422054
# Precision: 0.5766423357664233
# ______________________________
# 2 of 5
# ROC AUC: 0.7782908231425343
# Recall: 0.07604562737642585
# Precision: 0.6557377049180327
# ______________________________
# 3 of 5
# ROC AUC: 0.7550203024063574
# Recall: 0.13688212927756654
# Precision: 0.6486486486486487
# ______________________________
# 4 of 5
# ROC AUC: 0.7582093590064073
# Recall: 0.11692015209125475
# Precision: 0.6507936507936508
# ______________________________
# 5 of 5
# ROC AUC: 0.7626102694488666
# Recall: 0.11026615969581749
# Precision: 0.58
# ______________________________

# %%
all_features = cv_score(LogisticRegression())
# Out:
# 1 of 5
# ROC AUC: 0.7332066591306136
# Recall: 0.10931558935361217
# Precision: 0.5066079295154186
# ______________________________
# 2 of 5
# ROC AUC: 0.768163395334498
# Recall: 0.1967680608365019
# Precision: 0.680921052631579
# ______________________________
# 3 of 5
# ROC AUC: 0.739254895930638
# Recall: 0.1682509505703422
# Precision: 0.5728155339805825
# ______________________________
# 4 of 5
# ROC AUC: 0.7304573920823082
# Recall: 0.10931558935361217
# Precision: 0.6216216216216216
# ______________________________
# 5 of 5
# ROC AUC: 0.7589411994947832
# Recall: 0.17490494296577946
# Precision: 0.6013071895424836
# ______________________________

# %% [markdown]
# We can see some improvements in scores.

# %% [markdown]
# ### Reverse Feature Elimination
#
# Selecting the columns based on backward selection can improve our results

# %%
model = LogisticRegression()
rfe = RFE(estimator=model, n_features_to_select=1, step=1)
rfe.fit(df, y)
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=1)

# %%
ranking_df = pd.DataFrame()
ranking_df['Feature_name'] = df.columns
ranking_df['Rank'] = rfe.ranking_

# %%
ranked = ranking_df.sort_values(by=['Rank'])
ranked
# Out:
#                       Feature_name  Rank
# 13                 current_balance     1
# 16   average_monthly_balance_prevQ     2
# 7               occupation_company     3
# 15  average_monthly_balance_prevQ2     4
# 21           current_month_balance     5
# 22          previous_month_balance     6
# 19             current_month_debit     7
# 10        occupation_self_employed     8
# 9              occupation_salaried     9
# 11              occupation_student    10
# 20            previous_month_debit    11
# 17            current_month_credit    12
# 12            customer_nw_category    13
# 2                           gender    14
# 8               occupation_retired    15
# 3                       dependents    16
# 14      previous_month_end_balance    17
# 1                              age    18
# 18           previous_month_credit    19
# 6      days_since_last_transaction    20
# 0                          vintage    21
# 4                             city    22
# 5                      branch_code    23

# %% [markdown]
# As we can see balance features are very important in our model.

# %%
top_10 = cv_score(LogisticRegression(), cols = ranked['Feature_name'][:10].values)
# Out:
# 1 of 5
# ROC AUC: 0.7986881101633954
# Recall: 0.22813688212927757
# Precision: 0.7361963190184049
# ______________________________
# 2 of 5
# ROC AUC: 0.8050442914397288
# Recall: 0.22338403041825095
# Precision: 0.7556270096463023
# ______________________________
# 3 of 5
# ROC AUC: 0.7985130070256687
# Recall: 0.22053231939163498
# Precision: 0.725
# ______________________________
# 4 of 5
# ROC AUC: 0.7935095616193245
# Recall: 0.21197718631178708
# Precision: 0.735973597359736
# ______________________________
# 5 of 5
# ROC AUC: 0.7942222838028076
# Recall: 0.19106463878326996
# Precision: 0.674496644295302
# ______________________________

# %% [markdown]
# Selecting the top 10 features gives better results in for our model.
#
# In order to correct recall scores we can try to change threshold value.

# %%
top_10 = cv_score(LogisticRegression(), cols = ranked['Feature_name'][:10].values, threshold=0.15)
# Out:
# 1 of 5
# ROC AUC: 0.7986881101633954
# Recall: 0.7994296577946768
# Precision: 0.32259301879555047
# ______________________________
# 2 of 5
# ROC AUC: 0.8050442914397288
# Recall: 0.8060836501901141
# Precision: 0.3332023575638507
# ______________________________
# 3 of 5
# ROC AUC: 0.7985130070256687
# Recall: 0.7994296577946768
# Precision: 0.3292873923257635
# ______________________________
# 4 of 5
# ROC AUC: 0.7935095616193245
# Recall: 0.7946768060836502
# Precision: 0.3235294117647059
# ______________________________
# 5 of 5
# ROC AUC: 0.7942222838028076
# Recall: 0.7908745247148289
# Precision: 0.3401471790678659
# ______________________________

# %% [markdown]
# We can see decreases in precision scores in our model. Improving ROC AUC results can be considered best case as we don't know  the metrics relevant to the business.
